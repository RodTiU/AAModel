# %%
include("AubryAndreModel.jl")
# Out:
# WARNING: replacing module AubryAndreModel.
# Main.AubryAndreModel

# %%
model = AubryAndreModel

matrix = model.hamiltonianMatrix(1, 750)

eigenVecs = model.eigenVectors(matrix)

graph = model.densityProfileVsLatticeIndexPlot(eigenVecs, true)
